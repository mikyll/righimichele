# %%
##############################################################
# virtualrobotCaller.py
##############################################################
## import socket
import time
import http.client
import urllib.request
from urllib import request, parse
import json

port = 8090               ## 8095 for demo0  8055 fro sentinel
## sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
 
alarmFire     = "msg(alarm,event,python,none,alarm(firetcp),1)"
alarmTsunami  = "msg(alarm,event,python,none,alarm(tsunamitcp),2)"

def connect(port) :
    server_address = ('192.168.1.7', port)
    ##sock.connect(server_address)    
    httpClient = http.client.HTTPConnection('localhost:8090')
    print("CONNECTED " , h1)

def emit( message ) :
    print("emit ", message)
    msg = message + "\n"
    byt=msg.encode()    #required in Python3
    sock.send(byt)

def workGet() :
    f = urllib.request.urlopen("http://localhost:8090")
    print(f.read())
def workPost() :
    # Data dict
    data =  {"robotmove":"turnRight", "time": 300}   
    # Dict to Json
    data = json.dumps(data)
    # Convert to String
    data = str(data)
    # Convert string to byte
    data = data.encode('utf-8')    
    print( data )
    req =  request.Request("http://localhost:8090/api/move",  data=data) # this will make the method "POST"
    resp = request.urlopen(req)  
    print(resp.read())
    
def anotherwork() :
    connection = http.client.HTTPConnection('http://localhost:8090', timeout=2)
    connection.request('GET', '/')
    response = connection.getresponse()
    content  = response.content.decode('utf-8')
    print("----------------------------")
    print(content.read())
    
    
def terminate() :
    ##sock.close()
    print("BYE")

###########################################    
workPost()
terminate()
